# %%
import llm_agent_helpers as q

# %%
question = "What import statements should I include to make calls to the OpenAI API?"

# %% [markdown]
# # Implement Markdown Display

# %%
q.ask_question(question, ui_mode=False)
# Out:
# To make calls to the OpenAI API using the OpenAI Python SDK, include this import statement:
#
# ```python
# from openai import OpenAI
# ```
#
# Then, you can create a client instance like this:
#
# ```python
# client = OpenAI()
# ```
#
# This setup allows you to call endpoints such as `client.chat.completions.create()`, `client.audio.transcriptions.create()`, and others according to your needs.

# %% [markdown]
# # Implement Gradio UI with no initial question passed in

# %%
q.ask_question(ui_mode=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7871
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7871/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Implement Gradio UI with initial question passed in

# %%
q.ask_question(question, ui_mode=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7872
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7872/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
q.reset_memory()
# Out:
# Conversation history reset.

# %%
q.ask_question("For the code you provided, what comes next?", ui_mode=False)
# Out:
# Could you please share the code you are referring to? That will help me provide the next steps.
